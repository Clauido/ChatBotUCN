# %%
from langchain_community.llms import Ollama

llm = Ollama(model="ucenin")

query = "¿ Que es un alumno regular?"

for chunks in llm.stream(query):
    print(chunks)
# Out:
# Lo
#  s
# iento
# ,
#  pero
#  la
#  información
#  proporcion
# ada
#  no
#  menc
# iona
#  expl
# íc
# it
# amente
#  qué
#  es
#  un
#  "
# al
# umno
#  regular
# "
#  en
#  el
#  contexto
#  de
#  la
#  Universidad
#  Cat
# ó
# lica
#  Del
#  Norte
#  -
#  Campus
#  Gu
# ay
# ac
# án
# .
#  Sin
#  embargo
# ,
#  puedo
#  ofrec
# erte
#  una
#  respuesta
#  general
#  bas
# ada
#  en
#  concept
# os
#  univers
# it
# arios
# .
#
#
# En
#  general
# ,
#  un
#  alumno
#  regular
#  se
#  ref
# iere
#  a
#  estudiantes
#  que
#  cumpl
# en
#  con
#  los
#  requis
# itos
#  y
#  polít
# icas
#  estable
# c
# idos
#  por
#  la
#  instit
# ución
#  acad
# ém
# ica
#  para
#  mantener
#  su
#  cond
# ición
#  de
#  mat
# r
# ícul
# a
#  activ
# a
# .
#  Esto
#  puede
#  incl
# uir
#  pagar
#  las
#  cu
# otas
#  correspond
# ientes
# ,
#  complet
# ar
#  cursos
#  o
#  unidades
#  de
#  estudio
#  según
#  el
#  calend
# ario
#  acad
# ém
# ico
# ,
#  y
#  ajust
# arse
#  a
#  los
# ...
